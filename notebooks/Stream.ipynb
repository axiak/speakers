# %%
# %matplotlib inline

from fir import *

# %%
wav_filename = '/home/axiak/Downloads/gtr-jazz.wav'

M = 1025
N = 4 * (M - 1)
(F_s, x) = read_wav(wav_filename)
N_ch = x.shape[1]
N_samples = x.shape[0]
print 'Applying -3 dB scaling to prevent clipping'
x = x * 0.7071
filt = FilterPrep(F_s, M)
coefs = filt.gen_lp(500., 1000., debug=True)
#coefs[:] = sum(coefs) / 1025.0
print F_s
print 'Computed FIR filter coefficients'
# Out:
# Applying -3 dB scaling to prevent clipping
# Please close figure window to continue
# 48000
# Computed FIR filter coefficients

# %%
o = OverlapSave(coefs, N, N_ch)
print 'Initialized overlap/save algorithm'

with StreamingPlayer(F_s, N_ch, device_index=7, stream_input=True, frames_per_buffer=1024) as p:
    while True:
        import time
        time.sleep(1)

    ##   Send samples through the filter to the player.
    #o.clear()
    #chunk = 1024
    #c = 0
    #max_samples = min(N_samples, 1e8)
    #while c < max_samples:
    #    samples_in = x[c:c+chunk]
    #    samples_out = o.process(samples_in)
    #    #   print 'After %d input samples: Got %s new output samples' % (c + chunk, samples_out.shape,)
    #    p.play_samples(samples_out)
    #    c += chunk
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /usr/share/AxiakDocs/speakers/fir.py in callback(self, in_data, frame_count, time_info, status)
#     256     def callback(self, in_data, frame_count, time_info, status):
#     257         if self.stream_input:
# --> 258             return self.stream_callback(in_data, frame_count, time_info, status)
#     259         else:
#     260             return self.wav_callback(in_data, frame_count, time_info, status)
#
# /usr/share/AxiakDocs/speakers/fir.py in stream_callback(self, in_data, frame_count, time_info, status)
#     261
#     262     def stream_callback(self, in_data, frame_count, time_info, status):
# --> 263         raise Exception(frame_count)
#     264         return '', pyaudio.paContinue
#     265
#
# Exception: 1024
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-969266c6350e> in <module>()
#       5 with StreamingPlayer(F_s, N_ch, device_index=7, stream_input=True, frames_per_buffer=1024) as p:
#       6     while True:
# ----> 7         import time
#       8         time.sleep(1)
#       9
#
# Exception:
# Initialized overlap/save algorithm

# %%
a = numpy.array([1, 2, 3, 4, 5, 6, 7, 8])
a.reshape((2, 4), order='F')
# Out:
# array([[1, 3, 5, 7],
#        [2, 4, 6, 8]])
