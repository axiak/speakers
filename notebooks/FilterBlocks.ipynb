# %%
# %matplotlib inline
import sys
import os
from matplotlib import pyplot
print os.getcwd()
sys.path.insert(0, '../')
from filter.filters import Filter, FilterFactory
# Out:
# D:\audio\speaker\axiak\speakers\notebooks
# Computing crc for ../filter\filters.py

# %%
ff = FilterFactory(48000, 1024)

# %%
filt_shelf1 = ff.shelf(1000, 2.0)
filt_shelf1
# Out:
# <shelf filter for 48000hz sample freq with 1024 taps>

# %%
filt_shelf2 = ff.shelf(600, -6)
filt_shelf2.plot()

filt_shelf2b = ff.apply_freq_limits(filt_shelf2, 0, 1000)
filt_shelf2b.plot()
# Out:
# Please close figure window to continue
# Please close figure window to continue

# %%
filt_gain = ff.gain(7.2)
filt_gain
# Out:
# <gain filter for 48000hz sample freq with 1024 taps>

# %%
filt_delay1 = ff.delay_sec(1.5e-3)
filt_delay1
# Out:
# <delay filter for 48000hz sample freq with 1024 taps>

# %%
filt_delay2 = ff.delay_deg(1000, 40)
filt_delay2
# Out:
# <delay filter for 48000hz sample freq with 1024 taps>

# %%
filt_slope1 = ff.spectral_slope(10, 1000, -4.0)
filt_slope1
# Out:
# <slope filter for 48000hz sample freq with 1024 taps>

# %%
filt_slope2 = ff.spectral_slope(300, 2000, -3.0)
filt_slope2
# Out:
# <slope filter for 48000hz sample freq with 1024 taps>

# %%
filt_eq1 = ff.parametric_eq(2000, 2.0, 4.0)
filt_eq1
# Out:
# <parametric filter for 48000hz sample freq with 1024 taps>

# %%
filt_eq2 = ff.parametric_eq(600, 0.5, 3.0)
filt_eq2
# Out:
# <parametric filter for 48000hz sample freq with 1024 taps>

# %%
filt_eq2 = ff.parametric_eq(4000, 5.0, -5.0)
filt_eq2
# Out:
# <parametric filter for 48000hz sample freq with 1024 taps>

# %%
filt_lp1 = ff.analog_lp2(1000, 0.707)
filt_lp1
# Out:
# <lp2 filter for 48000hz sample freq with 1024 taps>

# %%
filt_lp1b = ff.analog_lp2(2200, 1.5)
filt_lp1b.plot()
ff.
# Out:
# <lp2 filter for 48000hz sample freq with 1024 taps>

# %%
filt_hp1 = ff.analog_hp1(5000)
filt_hp1
# Out:
# <hp1 filter for 48000hz sample freq with 1024 taps>

# %%
bass = ff.analog_lp2(450, 1)
mid = (ff.analog_hp2(20, 1) * ff.analog_lp2(3300, 1))
tweeter = ff.analog_hp2(2200, 1)

(bass + mid + tweeter)
# Out:
# <hp2_add_hp2_conv_lp2_add_lp2 filter for 48000hz sample freq with 1024 taps: None + None * None + None>

# %%
ff.butter_filter(2, 200, 'highpass')
# Out:
# <butterworth filter for 48000hz sample freq with 1024 taps>
